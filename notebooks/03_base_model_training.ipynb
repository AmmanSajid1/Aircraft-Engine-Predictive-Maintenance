# %% [markdown]
# # Base Model Training

# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
os.chdir(r"C:\Users\amman\Documents\MLOPS\Aircraft-Engine-Predictive-Maintenance")
os.getcwd()
# Out:
# 'C:\\Users\\amman\\Documents\\MLOPS\\Aircraft-Engine-Predictive-Maintenance'

# %% [markdown]
# #### Load the data

# %%
train_df = pd.read_csv(r"data\processed\train_FD001_processed")
test_df = pd.read_csv(r"data\processed\test_FD001_processed")

# %%
train_df.head()
# Out:
#    sensor_2  sensor_3  sensor_4  sensor_7  sensor_8  sensor_9  sensor_11  \
# 0 -1.721725 -0.134255 -0.925936  1.121141 -0.516338 -0.862813  -0.266467
# 1 -1.061780  0.211528 -0.643726  0.431930 -0.798093 -0.958818  -0.191583
# 2 -0.661813 -0.413166 -0.525953  1.008155 -0.234584 -0.557139  -1.015303
# 3 -0.661813 -1.261314 -0.784831  1.222827  0.188048 -0.713826  -1.539489
# 4 -0.621816 -1.251528 -0.301518  0.714393 -0.516338 -0.457059  -0.977861
#
#    sensor_12  sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  \
# 0   0.334262  -1.058890  -0.269071  -0.603816  -0.781710   1.348493
# 1   1.174899  -0.363646  -0.642845  -0.275852  -0.781710   1.016528
# 2   1.364721  -0.919841  -0.551629  -0.649144  -2.073094   0.739891
# 3   1.961302  -0.224597  -0.520176  -1.971665  -0.781710   0.352598
# 4   1.052871  -0.780793  -0.521748  -0.339845  -0.136018   0.463253
#
#    sensor_21  RUL
# 0   1.194427  191
# 1   1.236922  190
# 2   0.503423  189
# 3   0.777792  188
# 4   1.059552  187

# %%
test_df.head()
# Out:
#    sensor_2  sensor_3  sensor_4  sensor_7  sensor_8  sensor_9  sensor_11  \
# 0 -0.201850 -1.517390 -1.113706  1.188932 -0.234584 -0.400453  -1.165071
# 1 -0.261846 -0.641513  0.210682  0.172064  0.047171 -0.927118   0.482370
# 2  0.398100 -0.126100  1.106199 -0.878699  0.892435 -0.723788   1.268649
# 3  0.198117  0.653544 -0.228188 -0.822207  0.469803 -0.631407   0.407486
# 4 -0.821799 -0.095110  1.158419 -0.087802  0.047171 -0.509590  -0.303908
#
#    sensor_12  sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  \
# 0   0.510525  -0.502695  -0.715188  -1.059765  -0.136018  -0.034694
# 1   0.442731  -0.085548  -0.883465   0.222760  -1.427402  -0.034694
# 2  -0.791108   0.609696  -0.644417  -0.806460   1.155367   0.629236
# 3   0.632553   0.192549  -0.530136   0.566722   1.155367  -1.307226
# 4  -0.560610   0.748745  -0.944275  -0.158531   0.509675  -0.366659
#
#    sensor_21  RUL
# 0   0.605041  112
# 1  -0.257790   98
# 2  -0.145087   69
# 3  -0.291971   82
# 4   1.126989   91

# %% [markdown]
# #### Create Train and Test splits

# %%
X_train = train_df
y_train = X_train.pop("RUL")
X_test = test_df 
y_test = X_test.pop("RUL")

# %% [markdown]
# #### Create model evauluation function

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2 = r2_score(true, predicted)
    
    return mae, mse, rmse, r2

# %% [markdown]
# #### Model Training

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "KNN Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "AdaBoost Regressor": AdaBoostRegressor(),
    "XGBRegressor": XGBRegressor(),
    "CatBoosting Regressor": CatBoostRegressor(verbose=False)
}

model_list = []
model_metrics = {}

for i in range(len(list(models))):

    # Train model
    model = list(models.values())[i]
    model.fit(X_train, y_train)

    # Model predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluate training and test sets
    model_train_mae, model_train_mse, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(list(models.keys())[i] + ":")
    model_list.append(list(models.keys())[i])

    model_metrics[model_list[-1]] = [model_train_mae, model_train_mse, model_train_rmse, model_train_r2, model_test_mae, model_test_mse, model_test_rmse, model_test_r2]
    


    print("Model Performance for Training Set")
    print("- Mean Absolute Error (MAE): {:.4f}".format(model_train_mae))
    print("- Mean Squared Error (MSE): {:.4f}".format(model_train_mse))
    print("- Root Mean Squared Error (RMSE) {:.4f}".format(model_train_rmse))
    print("- R2 Score: {:.4f}".format(model_train_r2))
    print("\n")
    print("Model Performance for Test Set")
    print("- Mean Absolute Error (MAE): {:.4f}".format(model_test_mae))
    print("- Mean Squared Error (MSE): {:.4f}".format(model_test_mse))
    print("- Root Mean Squared Error (RMSE) {:.4f}".format(model_test_rmse))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    

    print('='*35)
    print("\n")
# Out:
# Linear Regression:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 34.1153
# - Mean Squared Error (MSE): 1995.2473
# - Root Mean Squared Error (RMSE) 44.6682
# - R2 Score: 0.5794
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 25.5403
# - Mean Squared Error (MSE): 1020.9708
# - Root Mean Squared Error (RMSE) 31.9526
# - R2 Score: 0.4088
# ===================================
#
#
# Ridge:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 34.1153
# - Mean Squared Error (MSE): 1995.2473
# - Root Mean Squared Error (RMSE) 44.6682
# - R2 Score: 0.5794
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 25.5401
# - Mean Squared Error (MSE): 1020.9455
# - Root Mean Squared Error (RMSE) 31.9522
# - R2 Score: 0.4088
# ===================================
#
#
# Lasso:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 34.1001
# - Mean Squared Error (MSE): 1997.8162
# - Root Mean Squared Error (RMSE) 44.6969
# - R2 Score: 0.5789
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 25.6284
# - Mean Squared Error (MSE): 1024.7264
# - Root Mean Squared Error (RMSE) 32.0113
# - R2 Score: 0.4066
# ===================================
#
#
# KNN Regressor:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 26.2851
# - Mean Squared Error (MSE): 1378.1622
# - Root Mean Squared Error (RMSE) 37.1236
# - R2 Score: 0.7095
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 24.8120
# - Mean Squared Error (MSE): 1150.0096
# - Root Mean Squared Error (RMSE) 33.9118
# - R2 Score: 0.3340
# ===================================
#
#
# Decision Tree:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 0.0000
# - Mean Squared Error (MSE): 0.0000
# - Root Mean Squared Error (RMSE) 0.0000
# - R2 Score: 1.0000
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 34.4800
# - Mean Squared Error (MSE): 2295.9400
# - Root Mean Squared Error (RMSE) 47.9160
# - R2 Score: -0.3295
# ===================================
#
#
# Random Forest Regressor:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 10.9454
# - Mean Squared Error (MSE): 243.3003
# - Root Mean Squared Error (RMSE) 15.5981
# - R2 Score: 0.9487
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 24.1315
# - Mean Squared Error (MSE): 1120.9726
# - Root Mean Squared Error (RMSE) 33.4809
# - R2 Score: 0.3509
# ===================================
#
#
# AdaBoost Regressor:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 36.6784
# - Mean Squared Error (MSE): 2172.2930
# - Root Mean Squared Error (RMSE) 46.6079
# - R2 Score: 0.5421
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 37.0289
# - Mean Squared Error (MSE): 1986.2855
# - Root Mean Squared Error (RMSE) 44.5678
# - R2 Score: -0.1502
# ===================================
#
#
# XGBRegressor:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 20.1429
# - Mean Squared Error (MSE): 809.3823
# - Root Mean Squared Error (RMSE) 28.4496
# - R2 Score: 0.8294
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 25.5973
# - Mean Squared Error (MSE): 1392.5056
# - Root Mean Squared Error (RMSE) 37.3163
# - R2 Score: 0.1936
# ===================================
#
#
# CatBoosting Regressor:
# Model Performance for Training Set
# - Mean Absolute Error (MAE): 24.2411
# - Mean Squared Error (MSE): 1156.9542
# - Root Mean Squared Error (RMSE) 34.0140
# - R2 Score: 0.7561
#
#
# Model Performance for Test Set
# - Mean Absolute Error (MAE): 23.5890
# - Mean Squared Error (MSE): 1096.7600
# - Root Mean Squared Error (RMSE) 33.1174
# - R2 Score: 0.3649
# ===================================

# %% [markdown]
# ### Results

# %%
results = pd.DataFrame(model_metrics, index=["Train_MAE", "Train_MSE", "Train_RMSE", "Train_R2", "Test_MAE", "Test_MSE", "Test_RMSE", "Test_R2"]).T.sort_values("Test_RMSE")
results
# Out:
#                          Train_MAE    Train_MSE  Train_RMSE  Train_R2  \
# Ridge                    34.115273  1995.247341   44.668192  0.579449
# Linear Regression        34.115287  1995.247340   44.668192  0.579449
# Lasso                    34.100142  1997.816233   44.696938  0.578907
# CatBoosting Regressor    24.241091  1156.954235   34.014030  0.756141
# Random Forest Regressor  10.945419   243.300304   15.598087  0.948718
# KNN Regressor            26.285115  1378.162162   37.123607  0.709516
# XGBRegressor             20.142942   809.382324   28.449645  0.829401
# AdaBoost Regressor       36.678372  2172.293008   46.607864  0.542132
# Decision Tree             0.000000     0.000000    0.000000  1.000000
#
#                           Test_MAE     Test_MSE  Test_RMSE   Test_R2
# Ridge                    25.540133  1020.945492  31.952238  0.408788
# Linear Regression        25.540327  1020.970757  31.952633  0.408774
# Lasso                    25.628435  1024.726444  32.011349  0.406599
# CatBoosting Regressor    23.588970  1096.759952  33.117366  0.364885
# Random Forest Regressor  24.131500  1120.972617  33.480929  0.350864
# KNN Regressor            24.812000  1150.009600  33.911791  0.334050
# XGBRegressor             25.597263  1392.505615  37.316292  0.193624
# AdaBoost Regressor       37.028883  1986.285531  44.567763 -0.150223
# Decision Tree            34.480000  2295.940000  47.915968 -0.329539
